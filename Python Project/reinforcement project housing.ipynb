# %% [markdown]
# Housing dataset

# %% [markdown]
# 1. Libraries

# %%
#import required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load csv file

# %%
df=pd.read_csv(r"C:/Users/Home/Downloads/housing.csv")
df
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# Copy dataset from the original dataset

# %%
#declare a variable to copy dataset from the original dataset

df_copydata = df.copy()
df_copydata
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#read first 5 rows of the dataset

df_copydata.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50       1340.0       NaN
# 1  02/05/2014 0:00  2384000.0         5       2.50       3650.0       NaN
# 2  02/05/2014 0:00   342000.0         3       2.00       1930.0       NaN
# 3  02/05/2014 0:00   420000.0         3       2.25       2000.0       NaN
# 4  02/05/2014 0:00   550000.0         4       2.50       1940.0       NaN
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0    1955.0
# 1     2.0           0     4          5        3370            280    1921.0
# 2     1.0           0     0          4        1930              0    1966.0
# 3     1.0           0     0          4        1000           1000    1963.0
# 4     1.0           0     0          4        1140            800    1976.0
#
# ...

# %%
#last 5 rows of the dataset

df_copydata.tail()
# Out:
#                  date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09/07/2014 0:00  308166.6667         3       1.75       1510.0
# 4596  09/07/2014 0:00  534333.3333         3       2.50       1460.0
# 4597  09/07/2014 0:00  416904.1667         3       2.50       3010.0
# 4598  10/07/2014 0:00  203400.0000         4       2.00       2090.0
# 4599  10/07/2014 0:00  220600.0000         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0       NaN          1979     501 N 143rd St    Seattle
# ...

# %%
#shape of the dataset

df_copydata.shape
# Out:
# (4600, 18)

# %%
#length of the dataset

len(df_copydata)
# Out:
# 4600

# %%
# sample from the dataset

df_copydata.sample(5)
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2114  09/06/2014 0:00  385000.0         3       1.75       1230.0    7500.0
# 1396  27/05/2014 0:00  500000.0         3       2.25       1760.0    4539.0
# 1686  02/06/2014 0:00  725995.0         4       2.50       3190.0    7869.0
# 2602  16/06/2014 0:00  340000.0         3       2.50       1212.0    1174.0
# 3466  26/06/2014 0:00  354000.0         4       2.50       2580.0    5476.0
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 2114     1.0           0     0          3        1230              0
# 1396     2.0           0     0          3        1760              0
# 1686     2.0           0     2          3        3190              0
# 2602     3.0           0     0          3        1212              0
# 3466     2.0           0     0          3        2580              0
#
#       yr_built  yr_renovated               street        city  statezip  \
# ...

# %%
# get a range of rows from the dataset

df_copydata.iloc[1:10]
# Out:
#               date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1  02/05/2014 0:00   2384000.0         5       2.50       3650.0       NaN
# 2  02/05/2014 0:00    342000.0         3       2.00       1930.0       NaN
# 3  02/05/2014 0:00    420000.0         3       2.25       2000.0       NaN
# 4  02/05/2014 0:00    550000.0         4       2.50       1940.0       NaN
# 5  02/05/2014 0:00    490000.0         2       1.00        880.0       NaN
# 6  02/05/2014 0:00    335000.0         2       2.00       1350.0       NaN
# 7  02/05/2014 0:00    482000.0         4       2.50       2710.0       NaN
# 8  02/05/2014 0:00  10000000.0         3       2.50       2430.0       NaN
# 9  02/05/2014 0:00    640000.0         4       2.00       1520.0       NaN
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 1     2.0           0     4          5        3370            280    1921.0
# ...

# %%
# information about dataset 

df_copydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4560 non-null   float64
#  5   sqft_lot       4586 non-null   float64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4577 non-null   float64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4543 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
# describe dataset

df_copydata.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4560.000000  4.586000e+03
# mean   5.539483e+05     3.400870     2.160815   2138.935526  1.485981e+04
# std    5.808371e+05     0.908848     0.783781    965.011449  3.592050e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.225000e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.610000e+05     3.000000     2.250000   1980.000000  7.683500e+03
# 75%    6.550000e+05     4.000000     2.500000   2620.000000  1.101850e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition    sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000   4600.000000
# mean      1.512065     0.007174     0.240652     3.451739   1840.825435
# std       0.538288     0.084404     0.778405     0.677230    970.705795
# ...

# %%
# datatype of each column

df_copydata.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built         float64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %% [markdown]
# Data cleaning

# %% [markdown]
# 1. Handle missing values
# 2. Remove duplicates
# 3. Correcting data type
# 4. Fixing inconsistent formatting or errors
# 5. Filtering outliers or irrelevant records

# %%
# missing values in the dataset

df_copydata.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living      40
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
#replace missing values with median

#sqft_living,sqft_lot,yr_built for numerical value 

df_copydata['sqft_living'] = df_copydata['sqft_living'].fillna(df_copydata['sqft_living'].median())
df_copydata['sqft_lot'] = df_copydata['sqft_lot'].fillna(df_copydata['sqft_lot'].median())
df_copydata['yr_built'] = df_copydata['yr_built'].fillna(df_copydata['yr_built'].median())

# %%
#replacing the missing value for categorical value

#city

df_copydata['city']=df_copydata['city'].fillna(df_copydata['city'].mode()[0])

# %%
#check whether the missing values are fill are not

df_copydata.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# Formatting

# %%
df_copydata.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built         float64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
# date

df_copydata['date']=pd.to_datetime(df_copydata['date'],errors='coerce')

# %%
#str.strip , str.title , str.upper 

df_copydata['street'] = df_copydata['street'].str.strip().str.title()
df_copydata['city'] = df_copydata['city'].str.strip().str.title()
df_copydata['statezip'] = df_copydata['statezip'].str.strip().str.upper()
df_copydata['country'] = df_copydata['country'].str.strip().str.title()

# %%
# yr_bulit convert float into int

df_copydata['yr_built']=df_copydata['yr_built'].astype('int')
df_copydata['bathrooms']=df_copydata['bathrooms'].astype('int')

# %%
#check whether datatype is changed or not 

df_copydata.dtypes
# Out:
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms                 int64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# street                   object
# city                     object
# statezip                 object
# country                  object
# dtype: object

# %%
df_copydata['waterfront'] = df_copydata['waterfront'].map({0: 'No', 1: 'Yes'})

# %%
condition_map = {
    1: 'Poor',
    2: 'Fair',
    3: 'Average',
    4: 'Good',
    5: 'Excellent'
}

df_copydata['condition'] = df_copydata['condition'].map(condition_map)

# %%
view_mapping = {
    0: "No view",
    1: "Poor view",
    2: "Average view",
    3: "Good view",
    4: "Excellent view"
}
# Apply the mapping
df_copydata['view'] = df_copydata['view'].map(view_mapping).astype(str)

# %% [markdown]
# Create a new column for the date

# %%
# create a new column in the dataset for year, month and day

df_copydata['year'] = df_copydata['date'].dt.year


df_copydata['month'] = df_copydata['date'].dt.month

df_copydata['day'] = df_copydata['date'].dt.day

# Display the first few rows to see the new columns
print(df_copydata[['date', 'year', 'month', 'day']].head())
# Out:
#         date    year  month  day
# 0 2014-02-05  2014.0    2.0  5.0
# 1 2014-02-05  2014.0    2.0  5.0
# 2 2014-02-05  2014.0    2.0  5.0
# 3 2014-02-05  2014.0    2.0  5.0
# 4 2014-02-05  2014.0    2.0  5.0

# %%
df_copydata['year'] = df_copydata['year'].astype('Int64')
df_copydata['month'] = df_copydata['month'].astype('Int64')
df_copydata['day'] = df_copydata['day'].astype('Int64')

df_copydata['floors'] = np.ceil(df_copydata['floors']).astype('int')

# %%
#weekdays

# Create 'weekday_name' column
df_copydata['weekday_name'] = df_copydata['date'].dt.day_name()

# Display the first few rows to see the new 'weekday_name' column
print(df_copydata[['date', 'weekday_name']].head())
# Out:
#         date weekday_name
# 0 2014-02-05    Wednesday
# 1 2014-02-05    Wednesday
# 2 2014-02-05    Wednesday
# 3 2014-02-05    Wednesday
# 4 2014-02-05    Wednesday

# %%
#count of the weekdays

df_copydata['weekday_name'].value_counts()
# Out:
# weekday_name
# Thursday     482
# Friday       392
# Tuesday      321
# Saturday     286
# Monday       274
# Sunday       230
# Wednesday     89
# Name: count, dtype: int64

# %% [markdown]
# Drop columns

# %%
# drop the colums

df_copydata.drop(['date', 'street',], axis=1, inplace=True)

# %%
df_copydata.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0   313000.0         3          1       1340.0    7683.5       2         No
# 1  2384000.0         5          2       3650.0    7683.5       2         No
# 2   342000.0         3          2       1930.0    7683.5       1         No
# 3   420000.0         3          2       2000.0    7683.5       1         No
# 4   550000.0         4          2       1940.0    7683.5       1         No
#
#              view  condition  sqft_above  sqft_basement  yr_built  \
# 0         No view    Average        1340              0      1955
# 1  Excellent view  Excellent        3370            280      1921
# 2         No view       Good        1930              0      1966
# 3         No view       Good        1000           1000      1963
# 4         No view       Good        1140            800      1976
#
#    yr_renovated       city  statezip country  year  month  day weekday_name
# ...

# %% [markdown]
# Duplicates

# %%
df_copydata.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Outliers / Anomalies

# %%
df_col = df_copydata.columns
df_col
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city', 'statezip', 'country', 'year',
#        'month', 'day', 'weekday_name'],
#       dtype='object')

# %%
plt.figure(figsize=(18, 5))
plt.boxplot(df[['price','bedrooms','bathrooms','sqft_living','sqft_lot',
                'floors','sqft_above','sqft_basement','yr_built','yr_renovated']])
plt.xticks(ticks=range(1, 11), 
           labels=['price','bedrooms','bathrooms','sqft_living','sqft_lot',
                   'floors','sqft_above','sqft_basement','yr_built','yr_renovated'], rotation=45)
plt.ylabel('Values')
plt.title('Box plot for numerical columns')
plt.show()

# %%
# Select only numeric columns
# Select specific columns from df and create a copy
numeric_col = df[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
                  'floors', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated']].copy()


# Loop over numeric columns and replace outliers
for i in range(10):  # You can reduce to 1 iteration; 10 is unnecessary unless the distribution changes a lot
    for col in numeric_col.columns:
        Q1 = df_copydata[col].quantile(0.25)
        Q3 = df_copydata[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        median_value = df_copydata[col].median()

        print(f"\nColumn: {col}")
        print(f"Lower bound: {lower_bound}")
        print(f"Upper bound: {upper_bound}")
        print(f"Median value: {median_value}")
        
        # Replace outliers with the rounded median
        df_copydata.loc[(df_copydata[col] < lower_bound) | (df_copydata[col] > upper_bound), col] = round(median_value, 0)
# Out:
# Column: price
# Lower bound: -176250.0
# Upper bound: 1153750.0
# Median value: 461000.0
#
# Column: bedrooms
# Lower bound: 1.5
# Upper bound: 5.5
# Median value: 3.0
#
# Column: bathrooms
# Lower bound: -0.5
# Upper bound: 3.5
# Median value: 2.0
#
# Column: sqft_living
# Lower bound: -240.0
# Upper bound: 4320.0
# Median value: 1980.0
#
# Column: sqft_lot
# Lower bound: -3997.5
# Upper bound: 19998.5
# Median value: 7683.5
#
# Column: floors
# Lower bound: -0.5
# Upper bound: 3.5
# Median value: 2.0
#
# Column: sqft_above
# Lower bound: -475.0
# Upper bound: 3965.0
# Median value: 1590.0
#
# Column: sqft_basement
# Lower bound: -915.0
# Upper bound: 1525.0
# Median value: 0.0
#
# Column: yr_built
# Lower bound: 1882.0
# Upper bound: 2066.0
# Median value: 1976.0
#
# Column: yr_renovated
# Lower bound: -2998.5
# Upper bound: 4997.5
# Median value: 0.0
#
# Column: price
# Lower bound: -93750.0
# Upper bound: 1016250.0
# Median value: 461000.0
#
# Column: bedrooms
# Lower bound: 1.5
# ...

# %%
plt.figure(figsize=(18, 5))
plt.boxplot(df_copydata[numeric_col.columns])
plt.xticks(ticks=range(1, len(numeric_col.columns)+1), 
           labels=numeric_col.columns, rotation=45)
plt.title('Boxplot After Outlier Replacement')
plt.show()

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# 1. Univariant analysis
# 2. Bivariant analysis
# 3. Multivariant analysis

# %% [markdown]
# Continuous variable of the dataframe
#
# 1. Price (target variable)
# 2. sqft_living
# 3. sqft_lot
# 4. sqft_above
# 5. sqft_basement
# 6. yr_bulit
# 7. yr_renovated
#
#
# Categorical variable of the dataframe
#
# 1. Bedrooms
# 2. Bathrooms
# 3. Floors
# 4. Waterfront
# 5. Views
# 6. Condition
# 7. City
# 8. Statezip
# 9. Country
# 10. Year
# 11. Month
# 12. Day

# %% [markdown]
# Univariant analysis

# %%
#univariant analysis

features = ['price', 'sqft_living', 'bedrooms', 'bathrooms']


for col in features:
    plt.figure(figsize=(6, 4))
    sns.histplot(df_copydata[col], kde=True, bins=30,color='green')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Bivariant analysis

# %%
#bivariant analysis

#relationship between pair of variable

#numerical vs numerical (price and sqft_footage)

sns.scatterplot(data=df_copydata,x='price',y='sqft_living',color='red')
plt.title('Price vs Sqft living')
plt.show()

# %%
# bedrooms vs bathrooms
import warnings
warnings.filterwarnings('ignore')
sns.barplot(data=df_copydata,x='bathrooms', y ='bedrooms',palette='Set2')
plt.title("Bedrooms vs Bathrooms")
plt.show()

# %%
sns.barplot(data=df_copydata, x='bathrooms', y='price',palette='Set2')
plt.title('Bathrooms vs Price')
plt.show()

# %% [markdown]
# Mulivariant analysis

# %%
# Select specific numeric columns
num = df_copydata[['price', 'bedrooms', 'bathrooms','sqft_living', 'sqft_lot','floors','sqft_above','sqft_basement','yr_built','yr_renovated']]

# Plot correlation heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(num.corr(), annot=True, fmt=".2f", cmap='viridis_r', square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
#pair plot 

sample_df = df_copydata[['price', 'sqft_living', 'bedrooms', 'bathrooms', 'floors', 'sqft_above']].sample(300)
sns.pairplot(sample_df)
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# Visualization

# %% [markdown]
# It is used to visualized to usnderstand trends , outliers and patterns
#
# 1. Histogram
# 2. Box plot
# 3. Scatter plots
# 4. Geographical pattern

# %%
#histogram (price)


plt.figure(figsize=(6, 4))
sns.histplot(df_copydata['price'], bins=50, kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Range')
plt.show()

# %%
# Boxplot for Price by Condition

import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(6, 4))
sns.boxplot(x='condition', y='price', data=df_copydata, palette='Set2')
plt.title("House Price by Condition")
plt.show()

# %%
import plotly.express as px

# Sample the data if it's too large for performance
sample_df = df_copydata.sample(500, random_state=1)  # optional

# Create interactive scatter plot
fig = px.scatter(
    sample_df,
    x='sqft_lot',
    y='price',
    hover_data=['price', 'sqft_lot'],
    title='Land Area vs House Price',
    labels={'sqft_lot': 'Land Area (sqft)', 'price': 'Price'}
)

fig.update_traces(marker=dict(size=6, color='blue'))
fig.update_layout(width=700, height=400)

fig.show()

# %%
#view vs price
import warnings
warnings.filterwarnings('ignore')

sns.barplot(data=df_copydata, x='view', y='price',palette='Set2')
plt.title('Views vs Price')
plt.show()

# %%
df_copydata['country'].unique()
# Out:
# array(['Usa'], dtype=object)

# %%
df_copydata['city'].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', 'Snoqualmie', 'Renton', 'Auburn',
#        'Sammamish', 'Kirkland', 'Issaquah', 'Des Moines', 'Federal Way',
#        'Duvall', 'Burien', 'Covington', 'Inglewood-Finn Hill', 'Kenmore',
#        'Carnation', 'Newcastle', 'Woodinville', 'Mercer Island',
#        'Black Diamond', 'Ravensdale', 'Bothell', 'Clyde Hill', 'Algona',
#        'Lake Forest Park', 'Skykomish', 'Normandy Park', 'Tukwila',
#        'Vashon', 'Fall City', 'Yarrow Point', 'Seatac', 'Medina',
#        'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village',
#        'Preston', 'Milton'], dtype=object)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from tqdm import tqdm
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.express as px

# Normalize city names
df_copydata['city'] = df_copydata['city'].str.strip().str.title()

# Fast coordinate mapping (add more if needed)
city_coords = {
    "Seattle": (47.6062, -122.3321), "Bellevue": (47.6101, -122.2015),
    "Redmond": (47.6739, -122.1215), "Shoreline": (47.7557, -122.3415),
    "Kent": (47.3809, -122.2348), "Maple Valley": (47.3923, -122.0461),
    "North Bend": (47.4934, -121.7868), "Snoqualmie": (47.5289, -121.8258),
    "Renton": (47.4829, -122.2171), "Auburn": (47.3073, -122.2285),
    "Sammamish": (47.6163, -122.0356), "Kirkland": (47.6815, -122.2087),
    "Issaquah": (47.5301, -122.0326), "Des Moines": (47.4018, -122.3241),
    "Federal Way": (47.3223, -122.3126), "Duvall": (47.7420, -121.9854),
    "Burien": (47.4704, -122.3468), "Covington": (47.3584, -122.1251),
    "Inglewood-Finn Hill": (47.7194, -122.2226), "Kenmore": (47.7573, -122.2440),
    "Carnation": (47.6484, -121.9146), "Newcastle": (47.5387, -122.1700),
    "Woodinville": (47.7543, -122.1635), "Mercer Island": (47.5707, -122.2221),
    "Black Diamond": (47.3207, -122.0037), "Ravensdale": (47.3515, -121.9730),
    "Bothell": (47.7623, -122.2054), "Clyde Hill": (47.6303, -122.2140),
    "Algona": (47.2762, -122.2546), "Lake Forest Park": (47.7563, -122.2896),
    "Skykomish": (47.7090, -121.3573), "Normandy Park": (47.4404, -122.3418),
    "Tukwila": (47.4739, -122.2604), "Vashon": (47.4473, -122.4596),
    "Fall City": (47.5670, -121.8885), "Yarrow Point": (47.6443, -122.2209),
    "Seatac": (47.4436, -122.3016), "Medina": (47.6200, -122.2268),
    "Enumclaw": (47.2040, -121.9915), "Snoqualmie Pass": (47.4211, -121.4122),
    "Pacific": (47.2646, -122.2501), "Beaux Arts Village": (47.5855, -122.2035),
    "Preston": (47.5282, -121.9690), "Milton": (47.2482, -122.3173)
}

# Assign coordinates
df_copydata['lat'] = df_copydata['city'].map(lambda x: city_coords.get(x, (None, None))[0])
df_copydata['lon'] = df_copydata['city'].map(lambda x: city_coords.get(x, (None, None))[1])
df_valid = df_copydata.dropna(subset=['lat', 'lon', 'price'])

# Map plot
fig = px.scatter_mapbox(
    df_valid, lat='lat', lon='lon', color='price', size='price',
    hover_name='city', hover_data={'price': ':.0f'}, zoom=9, height=600,
    title="USA House Prices"
)
fig.update_layout(mapbox_style="open-street-map", margin={"r":0,"t":50,"l":0,"b":0})
fig.show()

# %%
df_copydata[df_copydata['price'] == df_copydata['price'].min()]['city'].value_counts()
# Out:
# city
# Seattle             12
# Bellevue             5
# Sammamish            4
# Mercer Island        4
# Federal Way          3
# Clyde Hill           2
# Burien               2
# Lake Forest Park     2
# Snoqualmie           2
# Renton               2
# Issaquah             1
# Enumclaw             1
# Normandy Park        1
# Covington            1
# Kent                 1
# Seatac               1
# Kenmore              1
# Woodinville          1
# Maple Valley         1
# Black Diamond        1
# Auburn               1
# Name: count, dtype: int64

# %%
sns.barplot(x='waterfront', y='price', data=df_copydata, palette='Set2')
plt.title("Price Distribution: Waterfront vs Non-Waterfront")
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
df_copydata.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city', 'statezip', 'country', 'year',
#        'month', 'day', 'weekday_name', 'lat', 'lon'],
#       dtype='object')

# %%
df_copydata['day'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4595    7
# 4596    7
# 4597    7
# 4598    7
# 4599    7
# Name: day, Length: 4600, dtype: Int64>

# %%
sns.stripplot(x='day',y='price',data=df_copydata ,color='red')
plt.title("weekdays based on the price")
plt.show()

# %%
#time based avg house price vs month

import plotly.express as px

fig = px.bar(
    df_copydata.groupby('month')['price'].mean().reset_index(),
    x='month', y='price',
    title="Avg House Price by Month",
    labels={'price': 'Avg Price', 'month': 'Month'},
    color_discrete_sequence=['green']
)
fig.show()

# %%
#Structure-related Insights

#Floors vs Price

sns.barplot(x='floors', y='price', data=df_copydata, palette='Set2')
plt.title("Price by Number of Floors")
plt.show()

# %%
# Basement vs Price

sns.scatterplot(x='sqft_basement', y='price', data=df_copydata)
plt.title("Price vs Basement Area")
plt.show()

# %%
import plotly.express as px

df_2014 = df_copydata[df_copydata['year'] == 2014]
monthly_avg = df_2014.groupby('month')['price'].mean().reset_index()

fig = px.line(monthly_avg, x='month', y='price', title='Avg Price by Month in 2014', markers=True)
fig.show()

# %%
df_copydata['yr_built'].unique()
# Out:
# array([1955, 1921, 1966, 1963, 1976, 1938, 1989, 1985, 1945, 1948, 1909,
#        1980, 1939, 1965, 1956, 1997, 1987, 1983, 1923, 1954, 2005, 1991,
#        1959, 1920, 1979, 1951, 1967, 2004, 2014, 1995, 1944, 1992, 1957,
#        1978, 1974, 1950, 1990, 1949, 1968, 1977, 1996, 2001, 2000, 1929,
#        2006, 2008, 2009, 2012, 2013, 2007, 1986, 1973, 1988, 1900, 1928,
#        1982, 1960, 2003, 1998, 1942, 1908, 1958, 1971, 1975, 1961, 1924,
#        1902, 1962, 1953, 1999, 1994, 1930, 1984, 2010, 1912, 1947, 1916,
#        1940, 1970, 1952, 1964, 1926, 1905, 1969, 1903, 1943, 1993, 1946,
#        1910, 1904, 1981, 1906, 1922, 2011, 2002, 1917, 1913, 1914, 1937,
#        1925, 1932, 1918, 1972, 1941, 1919, 1936, 1911, 1927, 1931, 1901,
#        1907, 1915, 1935, 1933, 1934])

# %%
#yr_built vs price

fig = px.line(
    df_copydata.groupby('yr_built')['price'].mean().reset_index(),
    x='yr_built', y='price',
    title='Avg Price by Year Built',
    labels={'yr_built': 'Year', 'price': 'Avg Price'},
    markers=True
)
fig.update_layout(xaxis_tickangle=45)
fig.show()

# %%
df_copydata['yr_renovated'].unique()
# Out:
# array([2005,    0, 1992, 1994, 2010, 1988, 2009, 1969, 2000, 1979, 1989,
#        2014, 1999, 2003, 1983, 1997, 1912, 1923, 1954, 2011, 2001, 2013,
#        2006, 1972, 1985, 1998, 2004, 1958, 2008, 1970, 1982, 1986, 1996,
#        2002, 1971, 1990, 1956, 1945, 1984, 2012, 1993, 2007, 1981, 1974,
#        1963, 1968, 1995, 1934, 1953, 1966, 1955, 1987, 1960, 1978, 1980,
#        1948, 1991, 1913, 1977, 1975])

# %%
#yr_renovated vs price 


fig2 = px.line(
    df_copydata[df_copydata['yr_renovated'] > 0].groupby('yr_renovated')['price'].mean().reset_index(),
    x='yr_renovated', y='price',
    title='Avg Price vs Year Renovated',
    labels={'yr_renovated': 'Year Renovated', 'price': 'Avg Price'},
    markers=True
)
fig2.update_layout(xaxis_tickangle=45)
fig2.show()

# %%
#top 3 month based on average price 

top3_months = df_copydata.groupby('month')['price'].mean().nlargest(3)
plt.figure(figsize=(8,5))
sns.barplot(x=top3_months.index, y=top3_months.values, palette='viridis')
plt.title('Top 3 Months by Average Housing Price')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.tight_layout()
plt.show()

# %%
data = df_copydata[df_copydata['year'] == 2014]['bathrooms'].value_counts()

plt.pie(data, labels=data.index.astype(str), autopct='%1.1f%%', explode=[0.05]*len(data), colors=plt.cm.Accent.colors)
plt.title('Bedrooms Distribution in 2014')
plt.show()

# %%
df_col
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city', 'statezip', 'country', 'year',
#        'month', 'day', 'weekday_name'],
#       dtype='object')

# %%
#Weekdays vs Price

plt.figure(figsize=(8,5))

# Countplot to show count of houses sold on each weekday
sns.countplot(data=df_copydata, x='weekday_name', order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'], palette='viridis')

plt.title('Weekdays vs Price')
plt.xlabel('Weekday')
plt.ylabel('Count of weekdays')
plt.tight_layout()
plt.show()

# %%
# list out top 5 cities in usa

top_cty = df_copydata.groupby('city')['price'].mean().sort_values(ascending=False).head(5)
print(top_cty)


top_cty.plot(kind='bar', color='skyblue')
plt.title('Top 5 Cities by Avg House Price')
plt.xlabel('City')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# city
# Beaux Arts Village    745000.000000
# Redmond               612291.045614
# Sammamish             612240.387966
# Mercer Island         593108.829457
# Bellevue              572244.962603
# Name: price, dtype: float64

# %% [markdown]
# Feature engineering

# %%
#house age 

df_copydata['house_age'] = 2025 - df_copydata['yr_built']

# %%
#renovation age 

df_copydata['renovation_age'] = df_copydata['yr_renovated'].apply(lambda x: 2025 - x if x > 0 else 0)

# %%
#price_per_sqft

df_copydata['price_per_sqft'] = df_copydata['price'] / df_copydata['sqft_living']

# %%
#Is multi floor

df_copydata['multi_floor'] = (df_copydata['floors'] > 1).astype(int)

# %%
#Basement Ratio

df_copydata['basement_ratio'] = df_copydata['sqft_basement'] / df_copydata['sqft_living']

# %% [markdown]
# Visualization for these feature

# %%
avg_price_by_age = df_copydata.groupby('house_age')['price'].mean().reset_index()

sns.lineplot(x='house_age', y='price', data=avg_price_by_age)
plt.title('Average House Price by House Age')
plt.xlabel('House Age')
plt.ylabel('Average Price')
plt.show()

# %%
#price per sqft distribution

sns.histplot(df_copydata['price_per_sqft'], bins=30, kde=True)
plt.title('Distribution of Price per Sqft')
plt.show()

# %%
#renovation age vs price 

avg_price_line = df_copydata.groupby('renovation_age')['price'].mean().reset_index()

sns.lineplot(x='renovation_age', y='price', data=avg_price_line, marker='o')
plt.title('Trend: Renovation Age vs Average Price')
plt.xlabel('Renovation Age')
plt.ylabel('Average Price')
plt.show()

# %%
#Multi-Floor vs Single-Floor House Price Comparison

sns.barplot(x='multi_floor', y='price', data=df_copydata , palette='Set2')
plt.xticks([0, 1], ['Single Floor', 'Multi Floor'])
plt.title('House Price by Floor Type')
plt.show()

# %%
#Basement Ratio vs Price

fig = px.scatter(df_copydata, x='basement_ratio', y='price',
                 title='Basement Ratio vs House Price',
                 labels={'basement_ratio': 'Basement Ratio', 'price': 'Price'},
                 hover_data=['sqft_basement', 'sqft_living'])
fig.show()

# %% [markdown]
# Analysis and Interpretation

# %%
# Descriptive Statistics

df_copydata[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot']].describe()
# Out:
#                price     bedrooms    bathrooms  sqft_living      sqft_lot
# count    4600.000000  4600.000000  4600.000000  4600.000000   4600.000000
# mean   461630.855241     3.363261     1.738696  2012.634348   6837.873261
# std    187921.400563     0.794358     0.647794   728.949969   2556.285837
# min         0.000000     2.000000     0.000000   370.000000    638.000000
# 25%    322500.000000     3.000000     1.000000  1470.000000   5001.000000
# 50%    461000.000000     3.000000     2.000000  1980.000000   7683.500000
# 75%    575000.000000     4.000000     2.000000  2480.000000   8100.000000
# max    953007.000000     5.000000     3.000000  3990.000000  12731.000000

# %% [markdown]
# Two way t-test view vs price
#
# Hypothesis:
#
# H₀ (Null): Waterfront has no effect on price
#
# H₁ (Alt): Based on waterfront they  have a different mean price

# %%
from scipy.stats import ttest_ind

# Split data into two groups based on waterfront view
has_view = df_copydata[df_copydata['waterfront'] == 'Yes']['price']
no_view = df_copydata[df_copydata['waterfront'] == 'No']['price']

# Perform t-test
t_stat, p_value = ttest_ind(has_view, no_view, equal_var=False)

# Significance level
alpha = 0.05

# Print results
print(f"T-Statistic: {t_stat:.2f}")
print(f"P-Value: {p_value:.5f}")

# Interpret results
if p_value < alpha:
    print(f"Since p-value ({p_value:.5f}) < alpha ({alpha}), we reject the null hypothesis.")
    print("Conclusion: There is a significant difference in mean price between homes with and without a water view.")
else:
    print(f"Since p-value ({p_value:.5f}) >= alpha ({alpha}), we fail to reject the null hypothesis.")
    print("Conclusion: No significant difference in mean price between homes with and without a water view.")
# Out:
# T-Statistic: 0.70
# P-Value: 0.48945
# Since p-value (0.48945) >= alpha (0.05), we fail to reject the null hypothesis.
# Conclusion: No significant difference in mean price between homes with and without a water view.

# %% [markdown]
# One way anova
#
# Hypothesis:
#
# H₀: Mean price is the same across all views
#
# H₁: At least one view has different mean price

# %%
from scipy.stats import f_oneway

# Group price by condition
one_anova = [df_copydata[df_copydata['sqft_living'] == c]['price'].dropna() for c in df_copydata['sqft_living'].unique()]

# Perform one-way ANOVA
f_stat, p_value = f_oneway(*one_anova)

# Print results
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Significant difference in price across sqft_living.")
else:
    print("Conclusion: No significant difference in price across sqft_living.")
# Out:
# F-statistic: 4.803616928426773
# P-value: 3.063431949606018e-163
# Conclusion: Significant difference in price across sqft_living.

# %% [markdown]
# Chi - square
#
# The Chi-Square test checks if two categorical variables are independent (i.e., not related) or if there's a significant association between them.

# %%
from scipy.stats import chi2_contingency

# Create contingency table
contingency_table = pd.crosstab(df_copydata['renovation_age'], df_copydata['waterfront'])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output results
print("Chi-Square Statistic:", round(chi2, 2))
print("Degrees of Freedom:", dof)
print("P-Value:", round(p, 5))

if p < 0.05:
    print("Reject the null hypothesis - variables are not independent")
else:
    print("Fail to reject the null hypothesis - variables are independent")
# Out:
# Chi-Square Statistic: 258.07
# Degrees of Freedom: 59
# P-Value: 0.0
# Reject the null hypothesis - variables are not independent
